# %%
# !tritonserver --model-repository `pwd`/triton-serve-fil --log-verbose 1
# Out:
# I0626 02:15:21.864058 1180 pinned_memory_manager.cc:240] Pinned memory pool is created at '0x7f688e000000' with size 268435456
# I0626 02:15:21.864342 1180 cuda_memory_manager.cc:105] CUDA memory pool is created on device 0 with size 67108864
# I0626 02:15:21.865239 1180 model_config_utils.cc:645] Server side auto-completed config: name: "preprocessing"
# max_batch_size: 8
# input {
#   name: "AMOUNT"
#   data_type: TYPE_STRING
#   dims: 1
# }
# output {
#   name: "AMOUNT"
#   data_type: TYPE_FP32
#   dims: 1
# }
# instance_group {
#   count: 1
#   kind: KIND_GPU
# }
# parameters {
#   key: "EXECUTION_ENV_PATH"
#   value {
#     string_value: "$$TRITON_MODEL_DIRECTORY/rapids22.06_cuda11.5_py3.8.tar.gz"
#   }
# }
# backend: "python"
#
# W0626 02:15:21.865503 1180 model_repository_manager.cc:315] ignore version directory '.ipynb_checkpoints' which fails to convert to integral number
# I0626 02:15:21.865522 1180 model_repository_manager.cc:1191] loading: preprocessing:1
# ...
